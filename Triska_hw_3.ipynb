# %% [markdown]
# # Logistic regression  for Census dataset

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score

import pandas_profiling

# %%
cols = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation',
          'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'y']

# %%
df_train = pd.read_csv('adult.data', names=cols, header=None)
df_test = pd.read_csv('adult.test', names=cols, header=None).iloc[1:]

# %%
df_train.head(5)
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country       y
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
df_test.head()
# Out:
#   age   workclass    fnlwgt      education  education_num  \
# 1  25     Private  226802.0           11th            7.0
# 2  38     Private   89814.0        HS-grad            9.0
# 3  28   Local-gov  336951.0     Assoc-acdm           12.0
# 4  44     Private  160323.0   Some-college           10.0
# 5  18           ?  103497.0   Some-college           10.0
#
#         marital_status          occupation relationship    race      sex  \
# 1        Never-married   Machine-op-inspct    Own-child   Black     Male
# 2   Married-civ-spouse     Farming-fishing      Husband   White     Male
# 3   Married-civ-spouse     Protective-serv      Husband   White     Male
# 4   Married-civ-spouse   Machine-op-inspct      Husband   Black     Male
# 5        Never-married                   ?    Own-child   White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country        y
# 1           0.0           0.0            40.0   United-States   <=50K.
# 2           0.0           0.0            50.0   United-States   <=50K.
# 3           0.0           0.0            40.0   United-States    >50K.
# 4        7688.0           0.0            40.0   United-States    >50K.
# 5           0.0           0.0            30.0   United-States   <=50K.

# %% [markdown]
# # Strategy 1 -- Do not deal with missing values

# %%
num_cols = ["age", "fnlwgt", "education_num", "capital_gain", "capital_loss", "hours_per_week"]
cat_cols = [col for col in df_train.columns if col not in num_cols and col != "y"]
cat_cols
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country']

# %%
df_test.shape
# Out:
# (16281, 15)

# %%
df_train.shape
# Out:
# (32561, 15)

# %%
df_train.dropna(subset=cat_cols, axis=0)
df_test.dropna(subset=cat_cols, axis=0)
# Out:
#       age          workclass    fnlwgt      education  education_num  \
# 1      25            Private  226802.0           11th            7.0
# 2      38            Private   89814.0        HS-grad            9.0
# 3      28          Local-gov  336951.0     Assoc-acdm           12.0
# 4      44            Private  160323.0   Some-college           10.0
# 5      18                  ?  103497.0   Some-college           10.0
# 6      34            Private  198693.0           10th            6.0
# 7      29                  ?  227026.0        HS-grad            9.0
# 8      63   Self-emp-not-inc  104626.0    Prof-school           15.0
# 9      24            Private  369667.0   Some-college           10.0
# 10     55            Private  104996.0        7th-8th            4.0
# 11     65            Private  184454.0        HS-grad            9.0
# 12     36        Federal-gov  212465.0      Bachelors           13.0
# 13     26            Private   82091.0        HS-grad            9.0
# 14     58                  ?  299831.0        HS-grad            9.0
# 15     48            Private  279724.0        HS-grad            9.0
# 16     43            Private  346189.0        Masters           14.0
# 17     20          State-gov  444554.0   Some-college           10.0
# 18     43            Private  128354.0        HS-grad            9.0
# 19     37            Private   60548.0        HS-grad            9.0
# 20     40            Private   85019.0      Doctorate           16.0
# 21     34            Private  107914.0      Bachelors           13.0
# 22     34            Private  238588.0   Some-college           10.0
# 23     72                  ?  132015.0        7th-8th            4.0
# 24     25            Private  220931.0      Bachelors           13.0
# 25     25            Private  205947.0      Bachelors           13.0
# 26     45   Self-emp-not-inc  432824.0        HS-grad            9.0
# 27     22            Private  236427.0        HS-grad            9.0
# 28     23            Private  134446.0        HS-grad            9.0
# 29     54            Private   99516.0        HS-grad            9.0
# 30     32   Self-emp-not-inc  109282.0   Some-college           10.0
# ...    ..                ...       ...            ...            ...
# 16252  81                  ?   26711.0      Assoc-voc           11.0
# 16253  60            Private  117909.0      Assoc-voc           11.0
# 16254  39            Private  229647.0      Bachelors           13.0
# 16255  38            Private  149347.0        Masters           14.0
# 16256  43          Local-gov   23157.0        Masters           14.0
# 16257  23            Private   93977.0        HS-grad            9.0
# 16258  73       Self-emp-inc  159691.0   Some-college           10.0
# 16259  35            Private  176967.0   Some-college           10.0
# 16260  66            Private  344436.0        HS-grad            9.0
# 16261  27            Private  430340.0   Some-college           10.0
# 16262  40            Private  202168.0    Prof-school           15.0
# 16263  51            Private   82720.0        HS-grad            9.0
# 16264  22            Private  269623.0   Some-college           10.0
# 16265  64   Self-emp-not-inc  136405.0        HS-grad            9.0
# 16266  50          Local-gov  139347.0        Masters           14.0
# 16267  55            Private  224655.0        HS-grad            9.0
# 16268  38            Private  247547.0      Assoc-voc           11.0
# 16269  58            Private  292710.0     Assoc-acdm           12.0
# 16270  32            Private  173449.0        HS-grad            9.0
# 16271  48            Private  285570.0        HS-grad            9.0
# 16272  61            Private   89686.0        HS-grad            9.0
# 16273  31            Private  440129.0        HS-grad            9.0
# 16274  25            Private  350977.0        HS-grad            9.0
# 16275  48          Local-gov  349230.0        Masters           14.0
# 16276  33            Private  245211.0      Bachelors           13.0
# 16277  39            Private  215419.0      Bachelors           13.0
# 16278  64                  ?  321403.0        HS-grad            9.0
# 16279  38            Private  374983.0      Bachelors           13.0
# 16280  44            Private   83891.0      Bachelors           13.0
# 16281  35       Self-emp-inc  182148.0      Bachelors           13.0
#
#             marital_status          occupation     relationship  \
# 1            Never-married   Machine-op-inspct        Own-child
# 2       Married-civ-spouse     Farming-fishing          Husband
# 3       Married-civ-spouse     Protective-serv          Husband
# 4       Married-civ-spouse   Machine-op-inspct          Husband
# 5            Never-married                   ?        Own-child
# 6            Never-married       Other-service    Not-in-family
# 7            Never-married                   ?        Unmarried
# 8       Married-civ-spouse      Prof-specialty          Husband
# 9            Never-married       Other-service        Unmarried
# 10      Married-civ-spouse        Craft-repair          Husband
# 11      Married-civ-spouse   Machine-op-inspct          Husband
# 12      Married-civ-spouse        Adm-clerical          Husband
# 13           Never-married        Adm-clerical    Not-in-family
# 14      Married-civ-spouse                   ?          Husband
# 15      Married-civ-spouse   Machine-op-inspct          Husband
# 16      Married-civ-spouse     Exec-managerial          Husband
# 17           Never-married       Other-service        Own-child
# 18      Married-civ-spouse        Adm-clerical             Wife
# 19                 Widowed   Machine-op-inspct        Unmarried
# 20      Married-civ-spouse      Prof-specialty          Husband
# 21      Married-civ-spouse        Tech-support          Husband
# 22           Never-married       Other-service        Own-child
# 23                Divorced                   ?    Not-in-family
# 24           Never-married      Prof-specialty    Not-in-family
# 25      Married-civ-spouse      Prof-specialty          Husband
# 26      Married-civ-spouse        Craft-repair          Husband
# 27           Never-married        Adm-clerical        Own-child
# 28               Separated   Machine-op-inspct        Unmarried
# 29      Married-civ-spouse        Craft-repair          Husband
# 30           Never-married      Prof-specialty    Not-in-family
# ...                    ...                 ...              ...
# 16252   Married-civ-spouse                   ?          Husband
# 16253   Married-civ-spouse      Prof-specialty          Husband
# 16254        Never-married        Tech-support    Not-in-family
# 16255   Married-civ-spouse      Prof-specialty          Husband
# 16256   Married-civ-spouse     Exec-managerial          Husband
# 16257        Never-married   Machine-op-inspct        Own-child
# 16258             Divorced     Exec-managerial    Not-in-family
# 16259   Married-civ-spouse     Protective-serv          Husband
# 16260              Widowed               Sales   Other-relative
# 16261        Never-married               Sales    Not-in-family
# 16262   Married-civ-spouse      Prof-specialty          Husband
# 16263   Married-civ-spouse        Craft-repair          Husband
# 16264        Never-married        Craft-repair        Own-child
# 16265              Widowed     Farming-fishing    Not-in-family
# 16266   Married-civ-spouse      Prof-specialty             Wife
# 16267            Separated     Priv-house-serv    Not-in-family
# 16268        Never-married        Adm-clerical        Unmarried
# 16269             Divorced      Prof-specialty    Not-in-family
# 16270   Married-civ-spouse   Handlers-cleaners          Husband
# 16271   Married-civ-spouse        Adm-clerical          Husband
# 16272   Married-civ-spouse               Sales          Husband
# 16273   Married-civ-spouse        Craft-repair          Husband
# 16274        Never-married       Other-service        Own-child
# 16275             Divorced       Other-service    Not-in-family
# 16276        Never-married      Prof-specialty        Own-child
# 16277             Divorced      Prof-specialty    Not-in-family
# 16278              Widowed                   ?   Other-relative
# 16279   Married-civ-spouse      Prof-specialty          Husband
# 16280             Divorced        Adm-clerical        Own-child
# 16281   Married-civ-spouse     Exec-managerial          Husband
#
#                       race      sex  capital_gain  capital_loss  \
# 1                    Black     Male           0.0           0.0
# 2                    White     Male           0.0           0.0
# 3                    White     Male           0.0           0.0
# 4                    Black     Male        7688.0           0.0
# 5                    White   Female           0.0           0.0
# 6                    White     Male           0.0           0.0
# 7                    Black     Male           0.0           0.0
# 8                    White     Male        3103.0           0.0
# 9                    White   Female           0.0           0.0
# 10                   White     Male           0.0           0.0
# 11                   White     Male        6418.0           0.0
# 12                   White     Male           0.0           0.0
# 13                   White   Female           0.0           0.0
# 14                   White     Male           0.0           0.0
# 15                   White     Male        3103.0           0.0
# 16                   White     Male           0.0           0.0
# 17                   White     Male           0.0           0.0
# 18                   White   Female           0.0           0.0
# 19                   White   Female           0.0           0.0
# 20      Asian-Pac-Islander     Male           0.0           0.0
# 21                   White     Male           0.0           0.0
# 22                   Black   Female           0.0           0.0
# 23                   White   Female           0.0           0.0
# 24                   White     Male           0.0           0.0
# 25                   White     Male           0.0           0.0
# 26                   White     Male        7298.0           0.0
# 27                   White     Male           0.0           0.0
# 28                   Black     Male           0.0           0.0
# 29                   White     Male           0.0           0.0
# 30                   White     Male           0.0           0.0
# ...                    ...      ...           ...           ...
# 16252                White     Male        2936.0           0.0
# 16253                White     Male        7688.0           0.0
# 16254                White   Female           0.0        1669.0
# 16255                White     Male           0.0           0.0
# 16256                White     Male           0.0        1902.0
# 16257                White     Male           0.0           0.0
# 16258                White   Female           0.0           0.0
# 16259                White     Male           0.0           0.0
# 16260                White   Female           0.0           0.0
# 16261                White   Female           0.0           0.0
# 16262                White     Male       15024.0           0.0
# 16263                White     Male           0.0           0.0
# 16264                White     Male           0.0           0.0
# 16265                White     Male           0.0           0.0
# 16266                White   Female           0.0           0.0
# 16267                White   Female           0.0           0.0
# 16268                Black   Female           0.0           0.0
# 16269                White     Male           0.0           0.0
# 16270                White     Male           0.0           0.0
# 16271                White     Male           0.0           0.0
# 16272                White     Male           0.0           0.0
# 16273                White     Male           0.0           0.0
# 16274                White   Female           0.0           0.0
# 16275                White     Male           0.0           0.0
# 16276                White     Male           0.0           0.0
# 16277                White   Female           0.0           0.0
# 16278                Black     Male           0.0           0.0
# 16279                White     Male           0.0           0.0
# 16280   Asian-Pac-Islander     Male        5455.0           0.0
# 16281                White     Male           0.0           0.0
#
#        hours_per_week  native_country        y
# 1                40.0   United-States   <=50K.
# 2                50.0   United-States   <=50K.
# 3                40.0   United-States    >50K.
# 4                40.0   United-States    >50K.
# 5                30.0   United-States   <=50K.
# 6                30.0   United-States   <=50K.
# 7                40.0   United-States   <=50K.
# 8                32.0   United-States    >50K.
# 9                40.0   United-States   <=50K.
# 10               10.0   United-States   <=50K.
# 11               40.0   United-States    >50K.
# 12               40.0   United-States   <=50K.
# 13               39.0   United-States   <=50K.
# 14               35.0   United-States   <=50K.
# 15               48.0   United-States    >50K.
# 16               50.0   United-States    >50K.
# 17               25.0   United-States   <=50K.
# 18               30.0   United-States   <=50K.
# 19               20.0   United-States   <=50K.
# 20               45.0               ?    >50K.
# 21               47.0   United-States    >50K.
# 22               35.0   United-States   <=50K.
# 23                6.0   United-States   <=50K.
# 24               43.0            Peru   <=50K.
# 25               40.0   United-States   <=50K.
# 26               90.0   United-States    >50K.
# 27               20.0   United-States   <=50K.
# 28               54.0   United-States   <=50K.
# 29               35.0   United-States   <=50K.
# 30               60.0   United-States   <=50K.
# ...               ...             ...      ...
# 16252            20.0   United-States   <=50K.
# 16253            40.0   United-States    >50K.
# 16254            40.0   United-States   <=50K.
# 16255            50.0   United-States    >50K.
# 16256            50.0   United-States    >50K.
# 16257            40.0   United-States   <=50K.
# 16258            40.0   United-States   <=50K.
# 16259            40.0   United-States   <=50K.
# 16260             8.0   United-States   <=50K.
# 16261            45.0   United-States   <=50K.
# 16262            55.0   United-States    >50K.
# 16263            40.0   United-States   <=50K.
# 16264            40.0   United-States   <=50K.
# 16265            32.0   United-States   <=50K.
# 16266            40.0               ?    >50K.
# 16267            32.0   United-States   <=50K.
# 16268            40.0   United-States   <=50K.
# 16269            36.0   United-States   <=50K.
# 16270            40.0   United-States   <=50K.
# 16271            40.0   United-States   <=50K.
# 16272            48.0   United-States   <=50K.
# 16273            40.0   United-States   <=50K.
# 16274            40.0   United-States   <=50K.
# 16275            40.0   United-States   <=50K.
# 16276            40.0   United-States   <=50K.
# 16277            36.0   United-States   <=50K.
# 16278            40.0   United-States   <=50K.
# 16279            50.0   United-States   <=50K.
# 16280            40.0   United-States   <=50K.
# 16281            60.0   United-States    >50K.
#
# [16281 rows x 15 columns]

# %%
# drop rows from categorical columns with "?"
for item in cat_cols:
    df_train = df_train[~df_train[item].isin([" ?"])]
    df_test = df_test[~df_test[item].isin([' ?'])]

# %%
# transforming categorical values to numeric
df_train = pd.get_dummies(df_train, columns = cat_cols)
df_test = pd.get_dummies(df_test, columns = cat_cols)

# %% [markdown]
# ## Modelling

# %%
Y = df_train['y']
df_train.drop('y', axis=1, inplace=True)

x_train, x_test, y_train, y_test = train_test_split(df_train, Y)
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# C:\Users\schwajka\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# ### Train classification accuracy

# %%
train_acc_1 = model.score(x_train, y_train)
print("Train accuracy: ", train_acc_1)
# Out:
# Train accuracy:  0.7896202643561293

# %% [markdown]
# ### Test classification accuracy

# %%
test_acc_1 = metrics.accuracy_score(y_test, model.predict(x_test))
print("Test accuracy: ", test_acc_1)
# Out:
# Test accuracy:  0.7951200106086725

# %% [markdown]
# ### In conclusion, this strategy is indeed worh noting, though I believe there are some more effective ones :)

# %% [markdown]
# # Strategy 2 -- Global most common substitution

# %%
# reloading the data to try out the 2nd strategy
df_train2 = pd.read_csv('adult.data', names=cols, header=None)
df_test2 = pd.read_csv('adult.test', names=cols, header=None).iloc[1:]

# %%
# numeric imputation
numeric_imputer = SimpleImputer(missing_values = 0, strategy = 'median')
df_train2[['capital_loss', 'capital_gain']] = numeric_imputer.fit_transform(df_train2[['capital_loss', 'capital_gain']])
df_test2[['capital_loss', 'capital_gain']] = numeric_imputer.fit_transform(df_test2[['capital_loss', 'capital_gain']])

# %%
# categorical imputation
categoric_imputer = SimpleImputer(missing_values= ' ?', strategy='most_frequent')
df_train2[['workclass', 'occupation', 'native_country']] = categoric_imputer.fit_transform(df_train2[['workclass', 'occupation', 'native_country']])
df_test2[['workclass', 'occupation', 'native_country']] = categoric_imputer.fit_transform(df_test2[['workclass', 'occupation', 'native_country']])

# %%
# cat_cols.append("y")
# cat_cols

# %%
df_train2 = pd.get_dummies(df_train2, columns = cat_cols)
df_test2 = pd.get_dummies(df_test2, columns = cat_cols)

# %%
Y = df_train2['y']
df_train2.drop('y', axis=1, inplace=True)

x_train, x_test, y_train, y_test = train_test_split(df_train2, Y)
model = LogisticRegression()
model.fit(x_train, y_train)
model.fit(x_test, y_test)
# Out:
# C:\Users\schwajka\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\schwajka\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# ### Train classification accuracy

# %%
train_acc_2 = model.score(x_train, y_train)
print("Train accuracy: ", train_acc_2)
# Out:
# Train accuracy:  0.7746519246519247

# %% [markdown]
# ### Test classification accuracy

# %%
test_acc_2 = metrics.accuracy_score(y_test, model.predict(x_test))
print("Test accuracy: ", test_acc_2)
# Out:
# Test accuracy:  0.7831961675469844

# %% [markdown]
# ### Looks like this strategy works is a little less effective than the previous one
